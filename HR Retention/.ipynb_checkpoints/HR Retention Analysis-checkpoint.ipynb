# %% [markdown]
# ***
# <center><img src="https://cdn-icons-png.freepik.com/256/1436/1436653.png" width=70 height=70 /></center>
# <h1><center>Employee Retention</center></h1>
#
# **Context:**
#
# Hr Data Analytics
#
# This dataset contains information about employees who worked in a company.
#
#
#
# **Content:**
#
# Columns: Satisfactory Level, Number of Project, Average Monthly Hours, Time Spend Company, Promotion Last 5 Years, Department, Salary
#
#
#
# **Goal:**
#
# Define the reasons that have a direct and clear impact on employee retention (i.e. whether they leave the company or continue to work);
#
# Predict employee turn over.
# ***

# %% [markdown]
# ### Understand the business scenario and problem
#
# The HR department at Salifort Motors wants to take some initiatives to improve employee satisfaction levels at the company. They collected data from employees, but now they don’t know what to do with it.
#
# Your goals in this project are to analyze the data collected by the HR department and to build a model that predicts whether or not an employee will leave the company.
#
# If you can predict employees likely to quit, it might be possible to identify factors that contribute to their leaving. Because it is time-consuming and expensive to find, interview, and hire new employees, increasing employee retention will be beneficial to the company.

# %% [markdown]
# ### Dataset
#
#
# Variable  |Description |
# -----|-----|
# satisfaction_level|Employee-reported job satisfaction level [0&ndash;1]|
# last_evaluation|Score of employee's last performance review [0&ndash;1]|
# number_project|Number of projects employee contributes to|
# average_monthly_hours|Average number of hours employee worked per month|
# time_spend_company|How long the employee has been with the company (years)
# Work_accident|Whether or not the employee experienced an accident while at work
# left|Whether or not the employee left the company
# promotion_last_5years|Whether or not the employee was promoted in the last 5 years
# Department|The employee's department
# salary|The employee's salary (U.S. dollars)

# %%
labels_txt = {
    
    #PDAT adequate provider data indicator
    'PDAT':{1: 'Yes', 2: 'No'},  
     
     #AGECPOXR age in months when child had chicken
    'AGECPOXR': {1.0: '0-6 months', 2.0:'7-12 months', 3.0:'13-18 months', 4.0:'19-24 months',np.nan: 'Missing'},
    
     #HAD_CPOX did child ever have chicken pox
    'HAD_CPOX':{1:'Yes', 2:'No', 77:"Don't Know", 99: 'Refused'},
    
     #AGEGRP age category of child
    'AGEGRP':{1: '19-23 months', 2:'24-29 months', 3:'30-35 months'},
    
     #CBF_01 child ever fed breast milk
    'CBF_01':{1:'Yes', 2:'No', 77:"Don't know", 99:'Missing'},
    
     #CEN_REG census region
    'CEN_REG':{1:'Northeast', 2:'Midwest', 3:'Southwest', 4:'West'},
     
     #CWIC_01 child ever participated in WIC program
    'CWIC_01':{1:'Yes', 2:'No', 3:'Never heard of WIC', 77:"Don't know", 99:'Refused', np.nan:'Missing'},
        
     #CWIC_02 – child currently participating in WIC program
    'CWIC_02':{1.0:'Yes', 2.0:'No', 77.0:"Don't know", 99.0:'Refused', np.nan:'Missing'},
    
     #EDUC1 – education of the mother
     'EDUC1':{1: '< 12 years', 2:'12 years', 3:'> 12 years, not a college graduate', 4: 'College graduate'},
     
     #FRSTBRN – firstborn status of the child
     'FRSTBRN':{1: 'Yes', 2:'No'},
      
     #I_HISP_K HISPANIC ORIGIN OF CHILD
     'I_HISP_K':{1: 'Yes', 2:'No'},
    
     #INCPOV1 – poverty status (introduced in 2005; INCPOV1R used through 2004)
    
     'INCPOV1': {1: 'At or above poverty level, income > %75,000', 2: 'At or above poverty level, income <= $75,000',\
                 3:'Below poverty level', 4:'Not determined'},
     #LANGUAGE
    
     #M_AGEGRP2 – age group of mother (introduced in 2016; M_AGEGRP used through 2015)
     'M_AGEGRP2':{1: '<= 29 years', 2:'30 year or older'},
    
     #MARITAL2 – marital status of mother (Living with partner response option added to questionnaire in 2015)
     'MARITAL2':{1:'Currently married', 2:'Never married, widowed, divorced, separated, deceased, or living with partner'},
    
    #MOBIL_I
    
    
    'RACE_K':{1:'White only', 2:'Black Only', 3:'Other and multiple race'},
    
    # RACEETHK – race/ethnicity of child (introduced in 2002; RACEKIDR used in 1995-2001)
    
    'RACEETHK': {1:'Hispanic', 2:'White alone, non-Hispanic', 3:'Black alone, non-Hispanic', \
                 4:'All other races alone and multiple races non-Hispanic'},    
    
    #SEX – sex of child
    'SEX':{1:'Male', 2:'Female'},
    
     #PROV_FAC – provider facility type
    'PROV_FAC': {1.0:'All public facilities', 2.0:'All hospital facilities',3.0:'All private facilities',\
                 4.0:'All military/other facilities', 5.0:'Mixed types', np.nan:'Missing'},
    
    #VFC_ORDER – do child’s providers order vaccines for children from state/local health department? (introduced in 2006)
    
    'VFC_ORDER':{1.0:'All providers', 2.0:'Some but not all providers',3.0:'No providers', 4.0:'Unknown', np.nan:'Missing'},
    
    #REGISTRY – provider(s) reported child’s vaccination(s) to state or community immunization registry
    'REGISTRY':{1.0:'All providers', 2.0:'Some but not all providers',3.0:'No providers', 4.0:'Unknown', np.nan:'Missing'},
    
    #INS_STAT2_I – child’s current health insurance coverage status (introduced in 2017, INS_STAT_I used in 2016)     
    'INS_STAT2_I':{1.0:'Private insurance only', 2.0:'Any Medicaid',3.0:'Other insurance', 4.0:'Uninsured', np.nan:'Missing'},
    
    #INS_BREAK_I – child’s insurance history since birth (introduced in 2016)
    
    'INS_BREAK_I':{1.0:'Currently insured but uninsured since birth', 2.0:'Currently insured and never uninsured since birth',\
                   3.0:'Currently uninsured but insured since birth', 4.0:'Currently uninsured and never insured since birth',\
                   np.nan:'Missing'}    
    
    }

# %% [markdown]
# ### Import packages

# %%
import warnings
warnings.filterwarnings('ignore')

# Packages data manipulation
import pandas as pd
import numpy as np

# Packages data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Packages data preprocessing
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler

# Packages Regression and ML models
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB

# Packages for model selection 
from sklearn.model_selection import train_test_split, GridSearchCV

# Packages for model evaluation
from sklearn.metrics import accuracy_score, precision_score, recall_score,\
f1_score, confusion_matrix, ConfusionMatrixDisplay, classification_report

# Calculates feature importance
from sklearn.inspection import permutation_importance

# %% [markdown]
# ### Load dataset

# %%
hr = pd.read_csv("datasets/HR_capstone_dataset.csv")

hr.head(2)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium

# %% [markdown]
# ### Gather basic information about the data

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Gather descriptive statistics about the data

# %%
hr.describe().T.round(2)
# Out:
#                          count    mean    std    min     25%     50%     75%  \
# satisfaction_level     14999.0    0.61   0.25   0.09    0.44    0.64    0.82
# last_evaluation        14999.0    0.72   0.17   0.36    0.56    0.72    0.87
# number_project         14999.0    3.80   1.23   2.00    3.00    4.00    5.00
# average_montly_hours   14999.0  201.05  49.94  96.00  156.00  200.00  245.00
# time_spend_company     14999.0    3.50   1.46   2.00    3.00    3.00    4.00
# Work_accident          14999.0    0.14   0.35   0.00    0.00    0.00    0.00
# left                   14999.0    0.24   0.43   0.00    0.00    0.00    0.00
# promotion_last_5years  14999.0    0.02   0.14   0.00    0.00    0.00    0.00
#
#                          max
# satisfaction_level       1.0
# last_evaluation          1.0
# number_project           7.0
# average_montly_hours   310.0
# time_spend_company      10.0
# Work_accident            1.0
# left                     1.0
# promotion_last_5years    1.0

# %% [markdown]
# <img src="https://i.ibb.co/MB4VJzZ/bulb.png" width=100 height=100/>
#
# ## <center> Preliminary Insights </center>
#
# #### **Left (Target Variable):**
# The mean is 0.24, which indicates that there are 24% of the employees who left the company.;
#
# (Termination: 24%, Active: 76%) The target variable is not perfectly balanced, but I don't think that is necessary to solve the class imbalance;
#
#
# #### **Current Satisfaction Level Evaluation:**
# The mean is 0.61, which indicates that the level of satisfaction (ranging from 0 to 1) is modearate. It decresead a little from the last evaluation. Why is that? Let's try to find out!;
#
# #### **Previous Satisfaction Level Evaluation :**
# As I said, the level of satisfaction of the previous evaluation is slightly higher than the current one, 0.71;
#
# #### **Number of Projects:**
# On average the employees works on about 4 projects at the time;
#
# #### **Average Monthly Hours:**
# The average monthly hours is relatively large, considering a work hours by month ~160 hours. Just 25% of employees works around ~160. 50% works more than 200 hours monthly;
#
# #### **promotion_last_5years**
# Just 2% of the employees were promoted over the last 5 years
#
# #### time_spend_company (How long the employee has been with the company (years))
# three and a half year on average

# %% [markdown]
# #### Check Missing Values

# %%
hr.isna().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %% [markdown]
# #### Check duplicates

# %%
hr[hr.duplicated()].head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                 0.46             0.57               2
# 866                 0.41             0.46               2
# 1317                0.37             0.51               2
# 1368                0.41             0.52               2
# 1461                0.42             0.53               2
#
#       average_montly_hours  time_spend_company  Work_accident  left  \
# 396                    139                   3              0     1
# 866                    128                   3              0     1
# 1317                   127                   3              0     1
# 1368                   132                   3              0     1
# 1461                   142                   3              0     1
#
#       promotion_last_5years  Department  salary
# 396                       0       sales     low
# 866                       0  accounting     low
# 1317                      0       sales  medium
# ...

# %% [markdown]
# Google Exemplar Note:
#
# "The above output shows the first five occurences of rows that are duplicated farther down in the dataframe. How likely is it that these are legitimate entries? In other words, how plausible is it that two employees self-reported the exact same response for every column?
#
# You could perform a likelihood analysis by essentially applying Bayes' theorem and multiplying the probabilities of finding each value in each column, but this does not seem necessary. With several continuous variables across 10 columns, it seems very unlikely that these observations are legitimate. You can proceed by dropping them."

# %%
# Drop duplicates
hr_subset = hr.drop_duplicates(keep='first').copy()

# %% [markdown]
# ### Rename columns and decode the data for the purpose of EDA

# %%
# Rename columns with 
renamed_col = {'Work_accident':'work_accident',
               'average_montly_hours':'average_monthly_hours',
               'left': 'left_company',
               'Department':'department'       
                }

hr_subset.rename(columns= renamed_col, inplace=True)

hr_viz = hr_subset.copy()

# decoding the data for data viz
mapping = {1:'yes', 0:'no'}

hr_viz['work_accident'] = hr_viz['work_accident'].map(mapping)

hr_viz['left_company'] = hr_viz['left_company'].map(mapping)

hr_viz['promotion_last_5years'] = hr_viz['promotion_last_5years'].map(mapping)

# %% [markdown]
# Assign each column name to the corresponding type of variable

# %%
continous_var = list(hr_viz.select_dtypes('float').columns)
discrete_var = list(hr_viz.select_dtypes('int').columns)
categorical_var = list(hr_viz.select_dtypes('object').columns)

# %% [markdown]
# ### Check outliers

# %%
plt.figure(figsize=(10, 12))
plotnumber = 1

# Loop through each column
for col in continous_var+discrete_var:
    if plotnumber <= len(continous_var+discrete_var):
        plt.subplot(3, 2, plotnumber)
        ax = sns.boxplot(x=hr_subset[col])
        plt.title(col)
        plt.xlabel(' ')        
    plotnumber += 1

# %%
# calculate the Inter quartile range
iqr_time_spend_comp = np.quantile(hr_subset['time_spend_company'],0.75) - np.quantile(hr_subset['time_spend_company'],0.25)

# calculate the lower bownd
low_time_spend_comp = np.quantile(hr_subset['time_spend_company'],.25) - 1.5 * iqr_time_spend_comp

# calculate the upper bownd
upper_time_spend_comp = np.quantile(hr_subset['time_spend_company'],.75) + 1.5 * iqr_time_spend_comp

# %%
outliers = hr_subset[(hr_subset['time_spend_company']  < low_time_spend_comp) 
                      | (hr_subset['time_spend_company'] > upper_time_spend_comp)]
outliers
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 1                    0.80             0.86               5
# 17                   0.78             0.99               4
# 34                   0.84             0.87               4
# 47                   0.57             0.70               3
# 67                   0.90             0.98               4
# ...                   ...              ...             ...
# 11994                0.22             0.94               3
# 11995                0.90             0.55               3
# 11996                0.74             0.95               5
# 11997                0.85             0.54               3
# 11998                0.33             0.65               3
#
#        average_monthly_hours  time_spend_company  work_accident  left_company  \
# 1                        262                   6              0             1
# 17                       255                   6              0             1
# ...

# %% [markdown]
# ## plot the outliers

# %%
sns.barplot(data = outliers,
            x='time_spend_company',
            y = 'department',
           
            orient='h'            
                )
plt.title('Tenure (outliers) for department')
plt.ylabel(' ')
plt.xlabel(' ');

# %%
palette=['blue', 'red']

for num_var in discrete_var+continous_var:    

    fig, ax = plt.subplots(1, 2, figsize=(15, 3))   
    
    # Histograms    
    sns.histplot(data=hr_subset, 
                      x=num_var,
                      bins = 40,
                      kde=True,
                      hue='left_company',
                      palette=palette,
                      alpha=0.3,
                      ax=ax[0]                          
                ) 
    # Mean vertical line
    ax[0].axvline(np.mean(hr_subset[num_var]), color="red")   
    
    # Boxplots
    sns.boxplot(data=hr_subset, 
                     y=num_var,
                     hue='left_company',
                     palette=palette,
                     ax=ax[1]
                   );

# %% [markdown]
# <img src="https://i.ibb.co/MB4VJzZ/bulb.png" width=100 height=100/>
#
# ## <center> Insights </center>
#
# #### **Number of Projects:**
# Most employees works in 4-5 projects. Most of those who worked in more than 6 projects left the company. It seems that all employees that worked in 7 projects left. The boxplot shows that the employees who left worked in a wide range of projects;
#
# #### **Average Monthly Hours:**
# Most of the employees on average works between ~140 to ~260. It seems that all employees that worked 280+ left the company;
#
# #### **Current Satisfaction Level Evaluation:**
# Most of the employees evaluated above 0.5. The number of employees who evaluated between 0 and ~0.43 increased in the current evalution

# %%
# Check the average of satisfaction level across Departments
agg_satisfaction = (hr_subset.groupby('department')[['last_evaluation','satisfaction_level']]
                    .mean())

# %%
# Average of satisfaction
overal_avg_last_eval = np.mean(agg_satisfaction['last_evaluation']).round(2)
overal_avg_current_eval = np.mean(agg_satisfaction['satisfaction_level']).round(2)


plt.figure(figsize=(15,7))
plt.ylim(0.2,1)
plt.title('Evaluation Score by Department', fontsize=17);
plt.ylabel('Score')
plt.xlabel(' ')


# Last evaluation line
sns.lineplot(data=agg_satisfaction,
            x=agg_satisfaction.index,
            y= 'last_evaluation',
            label='Last Evaluation', color='blue')
# Text with the average
plt.text(x = 0.1, y = 0.75, s = f'Avg Last Evaluation: {overal_avg_last_eval}')

# Current evaluation line
sns.lineplot(data=agg_satisfaction,
            x=agg_satisfaction.index,
            y= 'satisfaction_level',
             label='Current Evaluation', color='green')

# Text with the average
plt.text(x = 0.1, y = 0.58, s = f'Avg Current Evaluation: {overal_avg_current_eval}');

# %% [markdown]
# <img src="https://i.ibb.co/MB4VJzZ/bulb.png" width=100 height=100/>
#
# ## <center> Insights </center>
#
# The level of satisfactions decreased significantly since the last evaluation. The decrese is slightly higher for the accounting department

# %%
# Create scatterplot of `average_monthly_hours` versus `satisfaction_level`, comparing employees who stayed versus those who left

fig, ax = plt.subplots(1, 2, figsize=(30, 10))   

sns.scatterplot(data=hr_subset, 
                x='average_monthly_hours', 
                y='last_evaluation', 
                hue='left_company', 
                alpha=0.4,
                palette=palette,
                ax=ax[0])

ax[0].axvline(x=166.67, color='#ff6361', label='166.67 hrs./mo.', ls='--')

ax[0].legend(labels=['166.67 hrs./mo.', 'stayed', 'left'])
ax[0].set_ylabel('Previous evaluation')
ax[0].set_title('Monthly hours by previous evaluation score', fontsize='14');

sns.scatterplot(data=hr_subset, 
                x='average_monthly_hours', 
                y='satisfaction_level', 
                hue='left_company', 
                alpha=0.4,
                palette=palette,
                ax=ax[1])

ax[1].axvline(x=166.67, color='#ff6361', label='166.67 hrs./mo.', ls='--')
ax[1].legend(labels=['166.67 hrs./mo.', 'stayed', 'left'])
ax[1].set_ylabel('Recent evaluation')
plt.title('Monthly hours by current evaluation score', fontsize='14');

# %%
avg_satisfaction_left = np.mean(hr_subset['satisfaction_level'][hr_subset['left_company'] == 1]).round(2)
avg_satisfaction_stayed = np.mean(hr_subset['satisfaction_level'][hr_subset['left_company'] == 0]).round(2)

avg_last_eval_left = np.mean(hr_subset['last_evaluation'][hr_subset['left_company'] == 1]).round(2)
avg_last_eval_stayed = np.mean(hr_subset['last_evaluation'][hr_subset['left_company'] == 0]).round(2)


plt.figure(figsize=(15,6))

# Plot last evaluation
sns.lineplot(data=hr_subset,
             x='average_monthly_hours',
             y='last_evaluation',
             hue='left_company',
             palette=palette,
             errorbar=None);

plt.legend(labels=['stayed', 'left'])
plt.title('Last Evaluation score by the Average of Monthly hours  ', fontsize=18)
plt.xlabel(' ')
plt.ylabel(' ')
plt.ylim(0,1)
plt.axhline(y=np.mean(hr_subset['last_evaluation'][hr_subset['left_company'] == 0]),linestyle='--', color='blue')
plt.text(x = 88, y = 0.55, s = f'Avg Satisfaction (stayed): {avg_last_eval_stayed}')
plt.axhline(y=np.mean(hr_subset['last_evaluation'][hr_subset['left_company'] == 1]),linestyle='--', color='red')
plt.axvline(x=166.67, color='green', label='166.67 hrs./mo.', ls='--')
plt.text(x = 88, y = 0.8, s = f'Avg Satisfaction (left): {avg_last_eval_left}')


# plot current evaluation
plt.figure(figsize=(15,5))
sns.lineplot(data=hr_subset,
             x='average_monthly_hours',
             y='satisfaction_level',
             hue='left_company',
             palette=palette,
             errorbar=None);

plt.legend(labels=['stayed', 'left'])
plt.title('Current Evaluation score by the Average of Monthly hours', fontsize=18)
plt.xlabel(' ')
plt.ylabel(' ')
min_ylim, max_ylim = plt.ylim()
plt.axhline(np.mean(hr_subset['satisfaction_level'][hr_subset['left_company'] == 0]), linestyle='--', color='blue')
plt.text(x = 88, y = 0.7, s = f'Avg Satisfaction (stayed): {avg_satisfaction_stayed}')
plt.axhline(np.mean(hr_subset['satisfaction_level'][hr_subset['left_company'] == 1]),linestyle='--', color='red')
plt.text(x = 88, y = 0.35, s = f'Avg Satisfaction (left): {avg_satisfaction_left}')
plt.axvline(x=166.67, color='green', label='166.67 hrs./mo.', ls='--')
plt.ylim(0,1);

# %% [markdown]
# <img src="https://i.ibb.co/MB4VJzZ/bulb.png" width=100 height=100/>
#
# ## <center> Insights </center>
#
# The last evaluation score was higher either for those who stayed as well for those who left.
#
# On the current evaluation score we can see that for those who stayed, the satisfaction level is basically the same, except for thos who worked on average more thatn 260 hours, which decreased considerably.
#
# For those who left, it seems that the satisfaction level deviated a little bit more for those who worked between ~170 and ~220 and decreased drastically for those who worked more than ~230 hours. The starting point usually starts above 166 hours
#
# Another thing that we could add, is that during this period, just 2% of employees were promoted. Maybe, they started working more hours, but the company wasn't given the right recognition, and turned out, they gave poor evaluations and left the company.

# %% [markdown]
# * ## Power BI Viz
# ### [Employee Retention](https://app.powerbi.com/view?r=eyJrIjoiZTQwZjFkZTItZTE5ZC00MjIxLTlmNTUtMTYxOGRkZjQzMWIyIiwidCI6IjhkODQwNjdkLTlhZDctNDU3Mi05YjEwLTEzM2QzNjQ2MmFhYSIsImMiOjF9)

# %% [markdown]
# <img src="https://i.ibb.co/0QKLQjx/2024-07-05-19-25-16-HR-Retention-Power-BI.png" width=1000 height=500/>

# %% [markdown]
# ## Encode the data

# %%
# instantiate Encoder class
enc = OrdinalEncoder()

# Ordinal encode the `salary` column
hr_subset['salary'] = enc.fit_transform(hr_subset[['salary']])

# Dummy encode the `department` column
df_enc = pd.get_dummies(hr_subset, drop_first=False, dtype='int')

# %%
# Create a heatmap to visualize how correlated variables are
plt.figure(figsize=(8, 6))
sns.heatmap(df_enc[['satisfaction_level', 'last_evaluation', 'number_project', 'average_monthly_hours', 'time_spend_company']]
            .corr(), annot=True, cmap="crest")
plt.title('Heatmap of the dataset')
plt.show()

# %% [markdown]
# ### Model Evaluation Function

# %% [markdown]
# First, let's create a function to save some time

# %%
def model_eval(model, X_train, y_train, X_test, y_test, y_pred):
    # Model name
    model_name = str(model).split('(')[0]
    
    target_names = ['Predicted would not leave', 'Predicted would leave']
    
    # classification report
    print(classification_report(y_test, y_pred, target_names=target_names))
    print('--'*40)
     
    # Confusion matrix heatmap    
    cm = confusion_matrix(y_test, y_pred, labels=model.classes_)

    disp = ConfusionMatrixDisplay(confusion_matrix=cm, 
                                      display_labels=model.classes_)

    # Plot confusion matrix
    disp.plot(values_format='')
    
    print(f'Confusion Matrix {model_name}')
    plt.show()
    
    print('--'*40)
    
    # plot the feature importance mean
    feature_importance = permutation_importance(model, X_train, y_train)
    
    plt.title(f'{model_name} Feature Importance')
    plt.ylabel(' ')
    plt.xlabel('Importance mean')
    plt.xlim(0,feature_importance['importances_mean'].max() * 1.2)
    sns.barplot(x=sorted(feature_importance['importances_mean'], reverse=True),
                y=X_train.columns);
    
    plt.show()

# %% [markdown]
# Create the dependent and independent variables

# %%
X = df_enc.drop(columns='left_company')
y = df_enc['left_company']

# %% [markdown]
# Split the data into training and testing. Since the class is unbalanced, let's stratify it

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25, 
                                                    stratify=y, 
                                                    random_state=42)

# %% [markdown]
# # 1. Logistic Regression (Accuracy: 0.82)

# %% [markdown]
# Since logistic regression is quite sensitive to outliers. Let's remove the outliers for the `time_spend_company`column

# %%
df_lr = df_enc[(df_enc['time_spend_company'] >= low_time_spend_comp) 
                   & (df_enc['time_spend_company'] <= upper_time_spend_comp)]

# %% [markdown]
# Create the dependent and independent variables

# %%
X_lr = df_lr.drop(columns='left_company')
y_lr = df_lr['left_company']

# %% [markdown]
# Split the data into training and testing set

# %%
X_train_lr, X_test_lr, y_train_lr, y_test_lr = train_test_split(X_lr, y_lr, 
                                                    test_size=0.25, 
                                                    stratify=y_lr, 
                                                    random_state=42)

# %%
# Construct a logistic regression model and fit it to the training dataset
lr = LogisticRegression(random_state=42, max_iter=500).fit(X_train_lr, y_train_lr)

# %%
y_pred_lr = lr.predict(X_test_lr)

# %%
model_eval(lr, X_train_lr, y_train_lr, X_test_lr, y_test_lr,  y_pred_lr)
# Out:
#                            precision    recall  f1-score   support
#
# Predicted would not leave       0.86      0.93      0.90      2321
#     Predicted would leave       0.45      0.27      0.34       471
#
#                  accuracy                           0.82      2792
#                 macro avg       0.66      0.60      0.62      2792
#              weighted avg       0.79      0.82      0.80      2792
#
# --------------------------------------------------------------------------------
# Confusion Matrix LogisticRegression
# --------------------------------------------------------------------------------

# %% [markdown]
# <img src="https://i.ibb.co/MB4VJzZ/bulb.png" width=100 height=100/>
#
# Although the overall precision, recall , f1-score and accuracy is considerably high (79%, 82%, 80%, 82% respectively). The model performed poorly. Recall that, the class is not in good balance (76% stayed, 24% left) most of these scores are due to the correctly prediction for 'Stayed'. Considering that our goal is to predict those who left, this is not a good model.
#
# More than a half of those who left were predicted incorrectly (False Negative).

# %% [markdown]
# # 2. Naive Bayes Classifier (Accuracy: 0.83)

# %%
nb = GaussianNB(priors=None)

# %%
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb.predict(X_test)

# %%
model_eval(nb, X_train, y_train, X_test, y_test,  y_pred_nb)
# Out:
#                            precision    recall  f1-score   support
#
# Predicted would not leave       0.93      0.86      0.89      2500
#     Predicted would leave       0.49      0.66      0.56       498
#
#                  accuracy                           0.83      2998
#                 macro avg       0.71      0.76      0.73      2998
#              weighted avg       0.86      0.83      0.84      2998
#
# --------------------------------------------------------------------------------
# Confusion Matrix GaussianNB
# --------------------------------------------------------------------------------

# %% [markdown]
# <img src="https://i.ibb.co/MB4VJzZ/bulb.png" width=100 height=100/>
#
# Slightly better than Logistic Regression, but still not good!

# %% [markdown]
# # 3. Random Forest (Accuracy: 98%)

# %% [markdown]
# ## Tuned Random Forest

# %%
# Instantiate model
rf = RandomForestClassifier(random_state=0)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth': [3,5, None], 
             'max_features': [1.0],
             'max_samples': [0.7, 1.0],
             'min_samples_leaf': [1,2,3],
             'min_samples_split': [2,3,4],
             'n_estimators': [300, 500],
             }  

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
rf1 = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
rf1.fit(X_train, y_train)

# %%
# Best parameters found through GridSearch
rf_best_params ={'max_depth': 5,
                 'max_features': 1.0,
                 'max_samples': 1.0,
                 'min_samples_leaf': 1,
                 'min_samples_split': 3,
                 'n_estimators': 300}

# %%
rf_opt = RandomForestClassifier(**rf_best_params, random_state=0)

# %%
rf_opt.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=1.0, max_samples=1.0,
#                        min_samples_split=3, n_estimators=300, random_state=0)

# %%
y_pred_rf_opt = rf_opt.predict(X_test)

# %%
model_eval(rf_opt, X_train, y_train, X_test, y_test, y_pred_rf_opt)
# Out:
#                            precision    recall  f1-score   support
#
# Predicted would not leave       0.98      0.99      0.99      2500
#     Predicted would leave       0.95      0.92      0.94       498
#
#                  accuracy                           0.98      2998
#                 macro avg       0.97      0.96      0.96      2998
#              weighted avg       0.98      0.98      0.98      2998
#
# --------------------------------------------------------------------------------
# Confusion Matrix RandomForestClassifier
# --------------------------------------------------------------------------------

# %% [markdown]
# <img src="https://i.ibb.co/MB4VJzZ/bulb.png" width=100 height=100/>
#
#
# Now we have a balanced result, or not?

# %% [markdown]
# <img src="https://www.dictionary.com/e/wp-content/uploads/2018/03/Thinking_Face_Emoji-Emoji-Island.png" width=30 height=30/> <center>"Something's wrong I can feel it. Just a feeling I've got... if that means, what I think it means, we are in trouble, big trouble..." (Rap God)</center>
#
# #### 99 is too good to be true! Let's check for data leakage
#
# ### The approach below was provided by the project exemplar

# %% [markdown]
# ### Feature Engineering
#
# "You might be skeptical of the high evaluation scores. There is a chance that there is some data leakage occurring. Data leakage is when you use data to train your model that should not be used during training, either because it appears in the test data or because it's not data that you'd expect to have when the model is actually deployed. Training a model with leaked data can give an unrealistic score that is not replicated in production.
#
# In this case, it's likely that the company won't have satisfaction levels reported for all of its employees. It's also possible that the average_monthly_hours column is a source of some data leakage. If employees have already decided upon quitting, or have already been identified by management as people to be fired, they may be working fewer hours.
#
# The first round of decision tree and random forest models included all variables as features. This next round will incorporate feature engineering to build improved models.
#
# You could proceed by dropping satisfaction_level and creating a new feature that roughly captures whether an employee is overworked. You could call this new feature overworked. It will be a binary variable"

# %%
# Drop `satisfaction_level` and save resulting dataframe in new variable
df2 = df_enc.drop('satisfaction_level', axis=1)

# Display first few rows of new dataframe
df2.head()
# Out:
#    last_evaluation  number_project  average_monthly_hours  time_spend_company  \
# 0             0.53               2                    157                   3
# 1             0.86               5                    262                   6
# 2             0.88               7                    272                   4
# 3             0.87               5                    223                   5
# 4             0.52               2                    159                   3
#
#    work_accident  left_company  promotion_last_5years  salary  department_IT  \
# 0              0             1                      0     1.0              0
# 1              0             1                      0     2.0              0
# 2              0             1                      0     2.0              0
# 3              0             1                      0     1.0              0
# 4              0             1                      0     1.0              0
#
# ...

# %%
# Create `overworked` column. For now, it's identical to average monthly hours.
df2['overworked'] = df2['average_monthly_hours']

# Inspect max and min average monthly hours values
print('Max hours:', df2['overworked'].max())
print('Min hours:', df2['overworked'].min())
# Out:
# Max hours: 310
# Min hours: 96

# %% [markdown]
# "166.67 is approximately the average number of monthly hours for someone who works 50 weeks per year, 5 days per week, 8 hours per day.
#
# You could define being overworked as working more than 175 hours per month on average.
#
# To make the overworked column binary, you could reassign the column using a boolean mask.
#
# df3['overworked'] > 175 creates a series of booleans, consisting of True for every value > 175 and False for every values ≤ 175
# .astype(int) converts all True to 1 and all False to 0"

# %%
# Define `overworked` as working > 175 hrs/week
df2['overworked'] = (df2['overworked'] > 175).astype(int)

# Display first few rows of new column
df2['overworked'].head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: overworked, dtype: int32

# %%
# Drop the `average_monthly_hours` column
df2 = df2.drop('average_monthly_hours', axis=1)

# Display first few rows of resulting dataframe
df2.head()
# Out:
#    last_evaluation  number_project  time_spend_company  work_accident  \
# 0             0.53               2                   3              0
# 1             0.86               5                   6              0
# 2             0.88               7                   4              0
# 3             0.87               5                   5              0
# 4             0.52               2                   3              0
#
#    left_company  promotion_last_5years  salary  department_IT  \
# 0             1                      0     1.0              0
# 1             1                      0     2.0              0
# 2             1                      0     2.0              0
# 3             1                      0     1.0              0
# 4             1                      0     1.0              0
#
#    department_RandD  department_accounting  department_hr  \
# 0                 0                      0              0
# ...

# %%
# Isolate the outcome variable
y = df2['left_company']

# Select the features
X = df2.drop('left_company', axis=1)

# %%
# Create test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y, random_state=0)

# %%
# Instantiate model
rf = RandomForestClassifier(random_state=0)

# Assign a dictionary of hyperparameters to search over
cv_params = {'max_depth': [3,5, None], 
             'max_features': [1.0],
             'max_samples': [0.7, 1.0],
             'min_samples_leaf': [1,2,3],
             'min_samples_split': [2,3,4],
             'n_estimators': [300, 500],
             }  

# Assign a dictionary of scoring metrics to capture
scoring = {'accuracy', 'precision', 'recall', 'f1', 'roc_auc'}

# Instantiate GridSearch
rf2 = GridSearchCV(rf, cv_params, scoring=scoring, cv=4, refit='roc_auc')

# %%
# %%time
rf2.fit(X_train, y_train)

# %%
rf2.best_params_
# Out:
# {'max_depth': 5,
#  'max_features': 1.0,
#  'max_samples': 1.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 4,
#  'n_estimators': 500}

# %%
# Best parameters found through GridSearch
rf_best_params ={'max_depth': 5,
                 'max_features': 1.0,
                 'max_samples': 1.0,
                 'min_samples_leaf': 1,
                 'min_samples_split': 4,
                 'n_estimators': 500}

# %%
rf2_opt = RandomForestClassifier(**rf_best_params, random_state=0)

# %%
rf2_opt.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, max_features=1.0, max_samples=1.0,
#                        min_samples_split=4, n_estimators=500, random_state=0)

# %%
y_pred_rf2_opt = rf2_opt.predict(X_test)

# %%
model_eval(rf2_opt, X_train, y_train, X_test, y_test, y_pred_rf2_opt)
# Out:
#                            precision    recall  f1-score   support
#
# Predicted would not leave       0.98      0.97      0.98      2500
#     Predicted would leave       0.87      0.91      0.89       498
#
#                  accuracy                           0.96      2998
#                 macro avg       0.93      0.94      0.93      2998
#              weighted avg       0.96      0.96      0.96      2998
#
# --------------------------------------------------------------------------------
# Confusion Matrix RandomForestClassifier
# --------------------------------------------------------------------------------

# %% [markdown]
# <img src="https://images.emojiterra.com/google/android-12l/512px/1f44d.png" width=100 height=100/>
#
# ### <center>  Good balance!!!! </center>

# %% [markdown]
# <img src="https://i.ibb.co/d7r3KSy/Benchmark.png" width=1000 height=300/>

# %% [markdown]
# # <center>Key takeaways: </center>
#
#
#
#
# * #### One of the most important factor that contributed for the high rate of turn over, was the high number of projects and high number of work hours.
#
# * #### Another thing to consider is that, it seems there's a lack of employees recognition by the company. Considering the low number of promotions.
